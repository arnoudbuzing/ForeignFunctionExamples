# %%
addone = ForeignFunctionLoad["./pointers.dylib", "addone", {"RawPointer"::["CInt"]} -> "CInt"]
# Out:
# ForeignFunction[/Users/arnoudb/ForeignFunctionExamples/pointers/pointers.dylib, addone,
#
# >   DataStructure[5208988032]]

# %%
ptr = RawMemoryAllocate["CInt"]
# Out:
# DataStructure[5788884512]

# %%
RawMemoryWrite[ptr, 5]
# Out:
# RawPointer[5183159984, CInt]

# %%
addone[ptr]
# Out:
# 0

# %%
RawMemoryRead[ptr]
# Out:
# 6
