# %%
square = ForeignFunctionLoad["./test.dylib", "square", {"Real64"} -> "Real64"]
# Out:
# ForeignFunction[/Users/arnoudb/foreign-function-interface/test.dylib, square,
#
# >   DataStructure[5470153728]]

# %%
square[2.0]
# Out:
# 4.

# %%
rotate = ForeignFunctionLoad["./test.dylib", "rotate", {{"Real64", "Real64"}, "Real64"} -> {"Real64", "Real64"}]
# Out:
# ForeignFunction[/Users/arnoudb/foreign-function-interface/test.dylib, rotate,
#
# >   DataStructure[5470156992]]

# %%
rotate[{1.0, 0.0}, Pi/2.0]
# Out:
#            -17
# {6.12323 10   , 1.}

# %%
Options[VerificationTest]
# Out:
# {MemoryConstraint -> Inherited, MetaInformation -> None, SameTest -> Inherited,
#
# >   TestID -> Automatic, TimeConstraint -> Inherited}

# %%
Panel[x]
# Out:
# Panel[x]

# %%
$Output
# Out:
# {OutputStream[stdout, 1]}
